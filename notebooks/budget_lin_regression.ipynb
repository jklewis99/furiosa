# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Import the dataset

# %%
dataset = pd.read_csv("../dbs/movies_from_2010s.csv")
dataset = dataset[['budget', 'revenue']]
dataset = dataset.loc[dataset['revenue'] > 0]
dataset = dataset.loc[dataset['budget'] > 0]
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values
dataset.head(5)
# Out:
#        budget      revenue
# 0  20000000.0   51416464.0
# 1  19000000.0   29922472.0
# 2  80000000.0  157107755.0
# 4  26000000.0   67918658.0
# 6  31000000.0   15134293.0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = regressor.predict(X_test)

# %%
plt.scatter(X_train, y_train, color='red')
plt.plot(X_train, regressor.predict(X_train), color='blue')
plt.title("Revenue vs Budget (training set)")
plt.xlabel("Budget (hundred millions)")
plt.ylabel("Revenue (Billions)")
plt.show() # adjsut scaling

# %%
plt.scatter(X_test, y_test, color='red')
plt.plot(X_test, predictions, color='blue')
plt.title("Revenue vs Budget (test set)")
plt.xlabel("Budget (hundred millions)")
plt.ylabel("Revenue (Billions)")
plt.show()
